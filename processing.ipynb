# %%
import json
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

from visualisation import *
from utils import *

# %%
with open('ferries.json', 'r') as file:
    ferries_data = json.load(file)
print(ferries_data)
# Out:
# {'fragancia': {'pontos_vessel_id': 'mmsi_265558290'}, 'jupiter': {'pontos_vessel_id': 'mmsi_265585310'}, 'merkurius': {'pontos_vessel_id': 'mmsi_265546940'}, 'nina': {'pontos_vessel_id': 'mmsi_265589970'}, 'yxlan': {'pontos_vessel_id': 'imo_8804440'}}

# %%
# Path to Excel file provided by Färjerederiet
file_path="./ferry_trips.xlsx"

# Load the Excel file into a Dataframe
ferry_trip_data = pd.read_excel(file_path)

# Get list of all ferries
ferries = list(ferry_trip_data["ferry_name"].unique())

# %%
# Add extra columns to the ferry_trip_data DataFrame
ferry_trip_data["fuelcons_outbound_l"] = None
ferry_trip_data["distance_outbound_nm"] = None
ferry_trip_data["start_time_outbound"] = None
ferry_trip_data["end_time_outbound"] = None

ferry_trip_data["fuelcons_inbound_l"] = None
ferry_trip_data["distance_inbound_nm"] = None
ferry_trip_data["start_time_inbound"] = None
ferry_trip_data["end_time_inbound"] = None

# %%
ferries = ["fragancia"]

# %%
# Time bucket
time_bucket = "30 seconds"  # Used to fetch data from PONTOS-HUB
time_bucket_s = 30  # Used to calculate fuel consumption

# Loop through all the ferries
for ferry in tqdm(ferries, desc="Processing ferries"):

    # Get a list of all the days in the time_departure column for the ferry
    days = ferry_trip_data[ferry_trip_data["ferry_name"].str.lower() == ferry][
        "time_departure"
    ].dt.date.unique()

    # Loop through all the days with a progress bar
    for day in tqdm(days, desc="Processing days"):

        # Get departure times for the day
        departure_times = ferry_trip_data[
            (ferry_trip_data["ferry_name"].str.lower() == ferry)
            & (ferry_trip_data["time_departure"].dt.date == day)
        ]["time_departure"]

        # Check if day is after PONTOS-HUB launch date
        if pd.Timestamp(day) <= pd.Timestamp("2023-04-30"):
            continue

        # Fetch vessel data from PONTOS-HUB
        start_of_day = pd.Timestamp(day)
        end_of_day = start_of_day + pd.Timedelta("1 day")
        vessel_data = fetch_vessel_data(
            ferries_data[ferry]["pontos_vessel_id"],
            str(start_of_day),
            str(end_of_day),
            time_bucket=time_bucket,
        )

        # If no vessel data is returned, skip to the next day
        if len(vessel_data) == 0:
            continue

        # Get trips from vessel data
        trips = get_trips_from_vessel_data(vessel_data)

        for departure_time in departure_times:

            # Identify outbound and inbound trips
            outbound_trip = None
            inbound_trip = None
            departure_time = pd.Timestamp(departure_time)
            closest_outbound_trip_index = min(
                range(len(trips)),
                key=lambda i: abs(pd.Timestamp(trips[i]["time"][0]) - departure_time),
            )
            closest_inbound_trip_index = (
                closest_outbound_trip_index + 1
                if closest_outbound_trip_index + 1 < len(trips)
                else closest_outbound_trip_index
            )
            closest_outbound_trip = trips[closest_outbound_trip_index]
            closest_inbound_trip = trips[closest_inbound_trip_index]
            if (
                abs(
                    (
                        pd.Timestamp(closest_outbound_trip["time"][0]) - departure_time
                    ).total_seconds()
                )
                / 60
                <= 5
            ):  # 5 minutes diff is acceptable
                outbound_trip = closest_outbound_trip
                if (
                    pd.Timestamp(closest_outbound_trip["time"][0])
                    - pd.Timestamp(closest_outbound_trip["time"][-1])
                ).total_seconds() / 60 <= 10:  # 10 minutes between first and last point is acceptable
                    inbound_trip = closest_inbound_trip

            distance_outbound_nm = None
            distance_inbound_nm = None
            fuelcons_outbound_l = None
            fuelcons_inbound_l = None
            start_time_outbound = None
            end_time_outbound = None
            start_time_inbound = None
            end_time_inbound = None

            if outbound_trip is not None:

                # Determine the start and end time for the outbound trip
                start_time_outbound = pd.Timestamp(outbound_trip["time"][0])
                end_time_outbound = pd.Timestamp(outbound_trip["time"][-1])

                # Calculate the total distance for the outbound trip
                distance_outbound_nm = sum(
                    [
                        haversine(
                            outbound_trip["path"][i], outbound_trip["path"][i - 1]
                        )
                        / 1_852
                        for i in range(1, len(outbound_trip["path"]))
                    ]
                )

                # Calculate the total fuel consumption for the outbound trip
                for key in outbound_trip.keys():
                    if "fuelcons_lph" in key:
                        if any([value == None for value in outbound_trip[key]]):
                            break
                        if fuelcons_outbound_l is None:
                            fuelcons_outbound_l = 0
                        fuelcons_outbound_l += sum(
                            [
                                fuelcons_lph * time_bucket_s / 3_600
                                for fuelcons_lph in outbound_trip[key]
                            ]
                        )

            if inbound_trip is not None:

                # Determine the start and end time for the inbound trip
                start_time_inbound = pd.Timestamp(inbound_trip["time"][0])
                end_time_inbound = pd.Timestamp(inbound_trip["time"][-1])

                # Calculate the total distance for the inbound trip
                distance_inbound_nm = sum(
                    [
                        haversine(inbound_trip["path"][i], inbound_trip["path"][i - 1])
                        / 1_852
                        for i in range(1, len(inbound_trip["path"]))
                    ]
                )

                # Calculate the total fuel consumption for the inbound trip
                for key in inbound_trip.keys():
                    if "fuelcons_lph" in key:
                        if any([value == None for value in inbound_trip[key]]):
                            break
                        if fuelcons_inbound_l is None:
                            fuelcons_inbound_l = 0
                        fuelcons_inbound_l += sum(
                            [
                                fuelcons_lph * time_bucket_s / 3_600
                                for fuelcons_lph in inbound_trip[key]
                            ]
                        )

            # Update ferry_trip_data DataFrame for the matching row
            row_mask = (ferry_trip_data["ferry_name"].str.lower() == ferry) & (
                ferry_trip_data["time_departure"] == departure_time
            )
            ferry_trip_data.loc[row_mask, "fuelcons_outbound_l"] = fuelcons_outbound_l
            ferry_trip_data.loc[row_mask, "distance_outbound_nm"] = distance_outbound_nm
            ferry_trip_data.loc[row_mask, "start_time_outbound"] = start_time_outbound
            ferry_trip_data.loc[row_mask, "end_time_outbound"] = end_time_outbound

            ferry_trip_data.loc[row_mask, "fuelcons_inbound_l"] = fuelcons_inbound_l
            ferry_trip_data.loc[row_mask, "distance_inbound_nm"] = distance_inbound_nm
            ferry_trip_data.loc[row_mask, "start_time_inbound"] = start_time_inbound
            ferry_trip_data.loc[row_mask, "end_time_inbound"] = end_time_inbound
# Out:
# Ferry: fragancia
# Processing days:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/felipe/miniconda3/envs/hack-a-fleet-v2/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
trv_data.iloc[7208].to_csv('trv_data_subset.csv', index=False)

# %%
df["avg_time"] = pd.to_datetime(df["avg_time"], format="ISO8601")
df["time"] = pd.to_datetime(df["time"], format="ISO8601")

# %%
trv_data.loc[row_mask]
# Out:
#       route_id    route_name ferry_name  ferry_id  \
# 7208        17  Oxdjupsleden  Fragancia       289
#
#                                      terminal_departure  \
# 7208  Rindö                                         ...
#
#                                        terminal_arrival      time_departure  \
# 7208  Värmdö                                        ... 2023-07-29 22:50:00
#
#       cars_outbound  trucks_outbound  trucks_with_trailer_outbound  ...  \
# 7208              2                0                             0  ...
#
#       passenger_car_equivalent_outbound  passenger_car_equivalent_inbound  \
# 7208                                2.0                               0.0
#
#       fuelcons_outbound_l  distance_outbound_nm  start_time_outbound  \
# 7208             3.552028              0.219289  2023-07-29 22:50:44
#
#         end_time_outbound  fuelcons_inbound_l  distance_inbound_nm  \
# 7208  2023-07-29 22:53:14            3.093528             0.220158
#
#        start_time_inbound     end_time_inbound
# 7208  2023-07-29 22:55:14  2023-07-29 22:57:44
#
# [1 rows x 38 columns]

# %%
df.head()
# Out:
#                       bucket       vessel_id               parameter_id  \
# 0  2023-07-29T00:00:00+00:00  mmsi_265558290  enginemain_fuelcons_lph_1
# 1  2023-07-29T00:00:00+00:00  mmsi_265558290  enginemain_fuelcons_lph_2
# 2  2023-07-29T00:00:00+00:00  mmsi_265558290  enginemain_fuelcons_lph_3
# 3  2023-07-29T00:00:00+00:00  mmsi_265558290  enginemain_fuelcons_lph_4
# 4  2023-07-29T00:00:00+00:00  mmsi_265558290     enginemain_speed_rpm_1
#
#                           avg_time  avg_value
# 0 2023-07-29 00:00:14.500000+00:00        0.0
# 1 2023-07-29 00:00:14.500000+00:00        0.0
# 2 2023-07-29 00:00:14.500000+00:00        0.0
# 3 2023-07-29 00:00:14.500000+00:00        0.0
# 4 2023-07-29 00:00:14.500000+00:00        0.0

# %%
haversine(path[0], path[1])
# Out:
# 75.39572078901556

# %%
 # Visualize trip clusters
r = plot_paths([trip["path"] for trip in trips], get_cluster_colors(labels))
r.to_html()
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~9.0.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 59.39555843873724,
#     &quot;longitude&quot;: 18.44512058367463,
#     &quot;zoom&quot;: 15
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;PathLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;color&quot;: [
#             31,
#             119,
#             180
#           ],
#           &quot;path&quot;: [
#             [
#               18.442134833333334,
#               59.395167566666665
#             ],
#             [
#               18.443462966666665,
#               59.395117133333336
#             ],
#             [
#               18.444982966666668,
#               59.39524993333333
#             ],
#             [
#               18.446430566666667,
#               59.39552296666667
#             ],
#             [
#               18.447553066666668,
#               59.3958021
#             ],
#             [
#               18.448149133333335,
#               59.396020033333336
#             ],
#             [
#               18.448439166666667,
#               59.39620503333333
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             255,
#             127,
#             14
#           ],
#           &quot;path&quot;: [
#             [
#               18.4480593,
#               59.39608616666667
#             ],
#             [
#               18.4469472,
#               59.3956131
#             ],
#             [
#               18.445381266666665,
#               59.395292766666664
#             ],
#             [
#               18.4436965,
#               59.39510463333333
#             ],
#             [
#               18.442440233333333,
#               59.39501406666667
#             ],
#             [
#               18.441812066666667,
#               59.3950553
#             ],
#             [
#               18.441519233333334,
#               59.39515813333333
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             31,
#             119,
#             180
#           ],
#           &quot;path&quot;: [
#             [
#               18.441835166666667,
#               59.39515443333333
#             ],
#             [
#               18.443016866666667,
#               59.39496103333333
#             ],
#             [
#               18.444515733333333,
#               59.394997133333334
#             ],
#             [
#               18.4460515,
#               59.395262566666666
#             ],
#             [
#               18.4473074,
#               59.3956379
#             ],
#             [
#               18.448124533333335,
#               59.39599843333333
#             ],
#             [
#               18.4485298,
#               59.3962716
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             255,
#             127,
#             14
#           ],
#           &quot;path&quot;: [
#             [
#               18.448051666666668,
#               59.3961494
#             ],
#             [
#               18.446828833333335,
#               59.395732933333335
#             ],
#             [
#               18.445215533333332,
#               59.395391133333334
#             ],
#             [
#               18.443596,
#               59.39515136666667
#             ],
#             [
#               18.442333,
#               59.3950654
#             ],
#             [
#               18.441685633333332,
#               59.39509233333333
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             31,
#             119,
#             180
#           ],
#           &quot;path&quot;: [
#             [
#               18.4417686,
#               59.39518373333333
#             ],
#             [
#               18.443172933333333,
#               59.395021
#             ],
#             [
#               18.4446501,
#               59.3951223
#             ],
#             [
#               18.445904466666665,
#               59.39538256666667
#             ],
#             [
#               18.446947266666665,
#               59.3956942
#             ],
#             [
#               18.447818766666668,
#               59.39595726666667
#             ],
#             [
#               18.448398733333335,
#               59.3962081
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             255,
#             127,
#             14
#           ],
#           &quot;path&quot;: [
#             [
#               18.448555033333335,
#               59.396358533333334
#             ],
#             [
#               18.447795,
#               59.3959725
#             ],
#             [
#               18.4461654,
#               59.3955647
#             ],
#             [
#               18.4442901,
#               59.39532056666667
#             ],
#             [
#               18.4427771,
#               59.39521343333333
#             ],
#             [
#               18.441906866666667,
#               59.3951795
#             ],
#             [
#               18.4414944,
#               59.39520786666667
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             31,
#             119,
#             180
#           ],
#           &quot;path&quot;: [
#             [
#               18.442141166666666,
#               59.3951988
#             ],
#             [
#               18.444108466666666,
#               59.39510203333333
#             ],
#             [
#               18.4460614,
#               59.3953542
#             ],
#             [
#               18.447335833333334,
#               59.395729466666666
#             ],
#             [
#               18.448126466666668,
#               59.39604573333333
#             ],
#             [
#               18.448515633333333,
#               59.3962851
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             255,
#             127,
#             14
#           ],
#           &quot;path&quot;: [
#             [
#               18.4484489,
#               59.3963616
#             ],
#             [
#               18.4474646,
#               59.396020533333335
#             ],
#             [
#               18.445852366666667,
#               59.3955902
#             ],
#             [
#               18.4439225,
#               59.39528043333333
#             ],
#             [
#               18.4423128,
#               59.395204633333336
#             ],
#             [
#               18.441558033333333,
#               59.3952368
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             31,
#             119,
#             180
#           ],
#           &quot;path&quot;: [
#             [
#               18.441983,
#               59.39529266666667
#             ],
#             [
#               18.443171866666667,
#               59.3953748
#             ],
#             [
#               18.444530266666668,
#               59.395558
#             ],
#             [
#               18.4458433,
#               59.395771266666664
#             ],

# %%
# Get a list of the ferries in the data
excel_ferries = list(data["farjenamn"].unique())
print(excel_ferries)
# Out:
# ['Fragancia', 'Jupiter', 'Merkurius', 'Nina', 'Yxlan']

# %%
ferries['fragancia']['pontos_id']
# Out:
# 'mmsi_265558290'

# %%
# Query a trip in the Excel file
averaged_vessel_data = fetch_vessel_data(ferries['fragancia']['pontos_id'],"2023-05-01T07:20:00","2023-05-01T08:20:00",['lat','lon'], time_bucket='5 minutes')

# %%
vessel_data = transform_averaged_vessel_data_to_dataframe(averaged_vessel_data)
vessel_data.head()
# Out:
# parameter_id                      positioningsystem_latitude_deg_1  \
# avg_time
# 2023-05-01 07:22:29.500000+00:00                         59.395435
# 2023-05-01 07:27:29.500000+00:00                         59.396061
# 2023-05-01 07:32:29.500000+00:00                         59.395233
# 2023-05-01 07:37:29.500000+00:00                         59.395284
# 2023-05-01 07:42:29.500000+00:00                         59.395282
#
# parameter_id                      positioningsystem_longitude_deg_1
# avg_time
# 2023-05-01 07:22:29.500000+00:00                          18.444900
# 2023-05-01 07:27:29.500000+00:00                          18.447614
# 2023-05-01 07:32:29.500000+00:00                          18.441523
# 2023-05-01 07:37:29.500000+00:00                          18.441312
# 2023-05-01 07:42:29.500000+00:00                          18.441305

# %%
vessel_track = vessel_data[["positioningsystem_latitude_deg_1", "positioningsystem_longitude_deg_1"]].values.tolist()
center_point = list(vessel_data[["positioningsystem_longitude_deg_1", "positioningsystem_latitude_deg_1"]].mean())

# %%
view_state = pdk.ViewState(latitude=center_point[1], longitude=center_point[0], zoom=10)

layer = pdk.Layer(
    type="ScatterplotLayer",
    data=vessel_data,
    get_position=["positioningsystem_longitude_deg_1","positioningsystem_latitude_deg_1"],
    pickable=True,
    get_fill_color=(255, 232, 0),
    get_radius=10,
)

r = pdk.Deck(layers=[layer], initial_view_state=view_state, tooltip={"text": "{name}"})
r.to_html("path_layer.html")
# Out:
#   Cell In[57], line 6
#     get_position=["positioningsystem_longitude_deg_1","positioningsystem_latitude_deg_1"]
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
import pydeck as pdk

DATA_URL = "https://raw.githubusercontent.com/visgl/deck.gl-data/master/website/bart-lines.json"
df = pd.read_json(DATA_URL)


def hex_to_rgb(h):
    h = h.lstrip("#")
    return tuple(int(h[i : i + 2], 16) for i in (0, 2, 4))


df["color"] = df["color"].apply(hex_to_rgb)


view_state = pdk.ViewState(latitude=37.782556, longitude=-122.3484867, zoom=10)

layer = pdk.Layer(
    type="PathLayer",
    data=df,
    pickable=True,
    get_color="color",
    width_scale=20,
    width_min_pixels=2,
    get_path="path",
    get_width=5,
)

r = pdk.Deck(layers=[layer], initial_view_state=view_state, tooltip={"text": "{name}"})
r.to_html("path_layer.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~9.0.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 37.782556,
#     &quot;longitude&quot;: -122.3484867,
#     &quot;zoom&quot;: 10
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;PathLayer&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;color&quot;: [
#             237,
#             28,
#             36
#           ],
#           &quot;name&quot;: &quot;Richmond - Millbrae&quot;,
#           &quot;path&quot;: [
#             [
#               -122.3535851,
#               37.9360513
#             ],
#             [
#               -122.3179784,
#               37.9249513
#             ],
#             [
#               -122.300284,
#               37.902646
#             ],
#             [
#               -122.2843653,
#               37.8735039
#             ],
#             [
#               -122.269058,
#               37.8694562
#             ],
#             [
#               -122.2709185,
#               37.85301
#             ],
#             [
#               -122.2689342,
#               37.8283973
#             ],
#             [
#               -122.2707195,
#               37.8080566
#             ],
#             [
#               -122.2718706,
#               37.804996
#             ],
#             [
#               -122.2948251,
#               37.8064628
#             ],
#             [
#               -122.3971496,
#               37.794745
#             ],
#             [
#               -122.4030149,
#               37.7905282
#             ],
#             [
#               -122.4084631,
#               37.7862646
#             ],
#             [
#               -122.4157833,
#               37.7803439
#             ],
#             [
#               -122.4219476,
#               37.7653052
#             ],
#             [
#               -122.4206096,
#               37.7528545
#             ],
#             [
#               -122.4359052,
#               37.7340058
#             ],
#             [
#               -122.448995,
#               37.723273
#             ],
#             [
#               -122.471192,
#               37.7067871
#             ],
#             [
#               -122.4672607,
#               37.6842548
#             ],
#             [
#               -122.4449822,
#               37.6635925
#             ],
#             [
#               -122.4169649,
#               37.6372339
#             ],
#             [
#               -122.3876274,
#               37.5993171
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             250,
#             166,
#             26
#           ],
#           &quot;name&quot;: &quot;Fremont - Richmond&quot;,
#           &quot;path&quot;: [
#             [
#               -122.353165,
#               37.936887
#             ],
#             [
#               -122.317269,
#               37.925655
#             ],
#             [
#               -122.299272,
#               37.903059
#             ],
#             [
#               -122.283451,
#               37.87404
#             ],
#             [
#               -122.268045,
#               37.869867
#             ],
#             [
#               -122.26978,
#               37.853024
#             ],
#             [
#               -122.2677961,
#               37.8284091
#             ],
#             [
#               -122.2695925,
#               37.8079322
#             ],
#             [
#               -122.2721546,
#               37.8035508
#             ],
#             [
#               -122.2666476,
#               37.7964139
#             ],
#             [
#               -122.2253433,
#               37.7739122
#             ],
#             [
#               -122.1985085,
#               37.7530763
#             ],
#             [
#               -122.1625282,
#               37.7216747
#             ],
#             [
#               -122.1280105,
#               37.6961822
#             ],
#             [
#               -122.0888196,
#               37.669805
#             ],
#             [
#               -122.0584803,
#               37.6342836
#             ],
#             [
#               -122.0187396,
#               37.5906334
#             ],
#             [
#               -121.9772135,
#               37.5567286
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             255,
#             232,
#             0
#           ],
#           &quot;name&quot;: &quot;Pittsburg/Bay Point - SFO&quot;,
#           &quot;path&quot;: [
#             [
#               -121.945154,
#               38.018914
#             ],
#             [
#               -122.024597,
#               38.003275
#             ],
#             [
#               -122.029095,
#               37.973737
#             ],
#             [
#               -122.056013,
#               37.928403
#             ],
#             [
#               -122.067423,
#               37.905628
#             ],
#             [
#               -122.123801,
#               37.893394
#             ],
#             [
#               -122.183791,
#               37.878361
#             ],
#             [
#               -122.251793,
#               37.844601
#             ],
#             [
#               -122.2666934,
#               37.8282587
#             ],
#             [
#               -122.2684655,
#               37.8078078
#             ],
#             [
#               -122.2715151,
#               37.80322
#             ],
#             [
#               -122.2947035,
#               37.8055689
#             ],
#             [
#               -122.3969458,
#               37.7938605
#             ],
#             [
#               -122.402211,
#               37.7898921
#             ],
#             [
#               -122.40766,
#               37.7856278
#             ],
#             [
#               -122.4147696,
#               37.779936
#             ],
#             [
#               -122.4208208,
#               37.7651836
#             ],
#             [
#               -122.4195378,
#               37.7525542
#             ],
#             [
#               -122.4349986,
#               37.7334634
#             ],
#             [
#               -122.4482045,
#               37.722627
#             ],
#             [
#               -122.4701365,
#               37.7064541
#             ],
#             [
#               -122.466233,
#               37.684638
#             ],
#             [
#               -122.444116,
#               37.664174
#             ],
#             [
#               -122.416038,
#               37.637753000000004
#             ],
#             [
#               -122.392612,
#               37.616035
#             ],
#             [
#               -122.38666,
#               37.599787
#             ]
#           ]
#         },
#         {
#           &quot;color&quot;: [
#             0,
#             174,
#             239
#           ],
#           &quot;name&quot;: &quot;Dublin/Pleasanton - Daly City&quot;,
#           &quot;path&quot;: [
#             [
#               -121.900367,
#               37.701695
#             ],
#             [
#               -121.928099,
#               37.699759
#             ],
#             [
#               -122

# %%
df
# Out:
#                             name           color  \
# 0            Richmond - Millbrae   (237, 28, 36)
# 1             Fremont - Richmond  (250, 166, 26)
# 2      Pittsburg/Bay Point - SFO   (255, 232, 0)
# 3  Dublin/Pleasanton - Daly City   (0, 174, 239)
# 4            Fremont - Daly City   (77, 184, 72)
#
#                                                 path
# 0  [[-122.3535851, 37.9360513], [-122.3179784, 37...
# 1  [[-122.353165, 37.936887], [-122.317269, 37.92...
# 2  [[-121.945154, 38.018914], [-122.024597, 38.00...
# 3  [[-121.900367, 37.701695], [-121.928099, 37.69...
# 4  [[-121.9764, 37.557355], [-122.017867, 37.5912...

# %%
response = query_pontos('https://pontos.ri.se/api/vessel_data_30_seconds_average?parameter_id=eq.positioningsystem_sog_kn_1&bucket=gte.2023-08-01T00:00:00&bucket=lt.2023-08-01T00:02:00&vessel_id=eq.mmsi_265585310&limit=10000')
response
# Out:
# [{'bucket': '2023-08-01T00:00:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2023-08-01T00:00:14.5+00:00',
#   'avg_value': 0.36},
#  {'bucket': '2023-08-01T00:00:30+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2023-08-01T00:00:44.5+00:00',
#   'avg_value': 3.0033333433333333},
#  {'bucket': '2023-08-01T00:01:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2023-08-01T00:01:14.5+00:00',
#   'avg_value': 5.56666669},
#  {'bucket': '2023-08-01T00:01:30+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2023-08-01T00:01:44.5+00:00',
#   'avg_value': 6.8533333333333335}]

# %%
response = query_pontos('https://pontos.ri.se/api/vessel_data?parameter_id=eq.positioningsystem_sog_kn_1&time=gte.2023-08-01T00:00:00&time=lt.2023-08-01T00:10:00&vessel_id=eq.mmsi_265585310&limit=10000')
total = 0
for row in response:
    total += float(row['value'])
print(f"Average value is {total / len(response)}")
response[0]
# Out:
# Average value is 5.1121664906666755
# {'time': '2023-08-01T00:09:59+00:00',
#  'vessel_id': 'mmsi_265585310',
#  'parameter_id': 'positioningsystem_sog_kn_1',
#  'value': '8.2'}

# %%
positions = get_vessel_data(ferries["jupiter"]["pontos_id"], limit=1000)
# Out:
# https://pontos.ri.se/api/vessel_data?parameter_id=ilike.*position*&time=gte.2023-10-29&time=lt.2023-10-30&vessel_id=eq.mmsi_265585310&limit=1000

# %%
def aggregate_vessel_data(data):
    # Convert the list of dictionaries into a DataFrame
    df = pd.DataFrame(data)

    # Convert the 'time' column to datetime format
    df['time'] = pd.to_datetime(df['time'])

    # Pivot the DataFrame to have parameter_ids as columns, time as rows
    pivot_df = df.pivot_table(index='time', columns='parameter_id', values='value', aggfunc='first')

    # Resample to every 5 seconds, using the last available value
    resampled_df = pivot_df.resample('10s').last().ffill()

    return resampled_df

# %%
aggregate_vessel_data(positions)
# Out:
# parameter_id              positioningsystem_cog_deg_1  \
# time
# 2023-10-29 23:55:50+00:00                       260.1
# 2023-10-29 23:56:00+00:00                       289.8
# 2023-10-29 23:56:10+00:00                       209.6
# 2023-10-29 23:56:20+00:00                       214.4
# 2023-10-29 23:56:30+00:00                       196.2
# 2023-10-29 23:56:40+00:00                       196.1
# 2023-10-29 23:56:50+00:00                       227.7
# 2023-10-29 23:57:00+00:00                         190
# 2023-10-29 23:57:10+00:00                       229.9
# 2023-10-29 23:57:20+00:00                       206.4
# 2023-10-29 23:57:30+00:00                         214
# 2023-10-29 23:57:40+00:00                       262.7
# 2023-10-29 23:57:50+00:00                       264.7
# 2023-10-29 23:58:00+00:00                       233.4
# 2023-10-29 23:58:10+00:00                       205.4
# 2023-10-29 23:58:20+00:00                       188.8
# 2023-10-29 23:58:30+00:00                       172.9
# 2023-10-29 23:58:40+00:00                       163.4
# 2023-10-29 23:58:50+00:00                       159.5
# 2023-10-29 23:59:00+00:00                       179.5
# 2023-10-29 23:59:10+00:00                       158.5
# 2023-10-29 23:59:20+00:00                        78.6
# 2023-10-29 23:59:30+00:00                         191
# 2023-10-29 23:59:40+00:00                       200.1
# 2023-10-29 23:59:50+00:00                       205.5
#
# parameter_id              positioningsystem_latitude_deg_1  \
# time
# 2023-10-29 23:55:50+00:00                         59.32089
# 2023-10-29 23:56:00+00:00                         59.32088
# 2023-10-29 23:56:10+00:00                        59.320877
# 2023-10-29 23:56:20+00:00                        59.320877
# 2023-10-29 23:56:30+00:00                        59.320873
# 2023-10-29 23:56:40+00:00                        59.320873
# 2023-10-29 23:56:50+00:00                        59.320873
# 2023-10-29 23:57:00+00:00                        59.320873
# 2023-10-29 23:57:10+00:00                        59.320873
# 2023-10-29 23:57:20+00:00                         59.32088
# 2023-10-29 23:57:30+00:00                         59.32089
# 2023-10-29 23:57:40+00:00                        59.320892
# 2023-10-29 23:57:50+00:00                         59.32089
# 2023-10-29 23:58:00+00:00                        59.320885
# 2023-10-29 23:58:10+00:00                        59.320885
# 2023-10-29 23:58:20+00:00                        59.320877
# 2023-10-29 23:58:30+00:00                        59.320877
# 2023-10-29 23:58:40+00:00                        59.320877
# 2023-10-29 23:58:50+00:00                        59.320877
# 2023-10-29 23:59:00+00:00                        59.320877
# 2023-10-29 23:59:10+00:00                        59.320873
# 2023-10-29 23:59:20+00:00                        59.320873
# 2023-10-29 23:59:30+00:00                        59.320873
# 2023-10-29 23:59:40+00:00                        59.320873
# 2023-10-29 23:59:50+00:00                        59.320873
#
# parameter_id              positioningsystem_longitude_deg_1  \
# time
# 2023-10-29 23:55:50+00:00                         18.099554
# 2023-10-29 23:56:00+00:00                         18.099556
# 2023-10-29 23:56:10+00:00                         18.099556
# 2023-10-29 23:56:20+00:00                         18.099556
# 2023-10-29 23:56:30+00:00                         18.099558
# 2023-10-29 23:56:40+00:00                         18.099567
# 2023-10-29 23:56:50+00:00                         18.099564
# 2023-10-29 23:57:00+00:00                         18.099554
# 2023-10-29 23:57:10+00:00                         18.099539
# 2023-10-29 23:57:20+00:00                          18.09953
# 2023-10-29 23:57:30+00:00                         18.099533
# 2023-10-29 23:57:40+00:00                         18.099535
# 2023-10-29 23:57:50+00:00                         18.099527
# 2023-10-29 23:58:00+00:00                         18.099525
# 2023-10-29 23:58:10+00:00                          18.09953
# 2023-10-29 23:58:20+00:00                         18.099533
# 2023-10-29 23:58:30+00:00                         18.099522
# 2023-10-29 23:58:40+00:00                         18.099516
# 2023-10-29 23:58:50+00:00                         18.099524
# 2023-10-29 23:59:00+00:00                         18.099539
# 2023-10-29 23:59:10+00:00                         18.099546
# 2023-10-29 23:59:20+00:00                         18.099552
# 2023-10-29 23:59:30+00:00                         18.099554
# 2023-10-29 23:59:40+00:00                         18.099556
# 2023-10-29 23:59:50+00:00                          18.09956
#
# parameter_id              positioningsystem_sog_kn_1
# time
# 2023-10-29 23:55:50+00:00                          0
# 2023-10-29 23:56:00+00:00                          0
# 2023-10-29 23:56:10+00:00                          0
# 2023-10-29 23:56:20+00:00                          0
# 2023-10-29 23:56:30+00:00                          0
# 2023-10-29 23:56:40+00:00                          0
# 2023-10-29 23:56:50+00:00                          0
# 2023-10-29 23:57:00+00:00                          0
# 2023-10-29 23:57:10+00:00                          0
# 2023-10-29 23:57:20+00:00                          0
# 2023-10-29 23:57:30+00:00                          0
# 2023-10-29 23:57:40+00:00                          0
# 2023-10-29 23:57:50+00:00                          0
# 2023-10-29 23:58:00+00:00                          0
# 2023-10-29 23:58:10+00:00                          0
# 2023-10-29 23:58:20+00:00                          0
# 2023-10-29 23:58:30+00:00                          0
# 2023-10-29 23:58:40+00:00                          0
# 2023-10-29 23:58:50+00:00                          0
# 2023-10-29 23:59:00+00:00                          0
# 2023-10-29 23:59:10+00:00                          0
# 2023-10-29 23:59:20+00:00                          0
# 2023-10-29 23:59:30+00:00                          0
# 2023-10-29 23:59:40+00:00                          0
# 2023-10-29 23:59:50+00:00                          0

# %%
# Calculate the date range for each vessel
date_ranges = data.groupby('farjenamn')['datumtid'].agg(['min', 'max'])
print(date_ranges)
# Out:
#                           min                 max
# farjenamn
# Fragancia 2023-03-01 05:44:00 2024-02-29 22:20:00
# Jupiter   2023-03-01 00:00:00 2024-02-29 23:00:00
# Merkurius 2023-03-01 00:00:00 2024-02-29 23:30:00
# Nina      2023-03-01 00:00:00 2024-02-29 21:30:00
# Yxlan     2023-03-01 05:30:00 2024-02-29 22:30:00

# %%
positions
# Out:
# [{'time': '2023-10-29T23:59:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09956'},
#  {'time': '2023-10-29T23:59:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '205.5'},
#  {'time': '2023-10-29T23:59:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09956'},
#  {'time': '2023-10-29T23:59:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '204'},
#  {'time': '2023-10-29T23:59:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:59:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '205.5'},
#  {'time': '2023-10-29T23:59:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:59:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '206.4'},
#  {'time': '2023-10-29T23:59:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '207.1'},
#  {'time': '2023-10-29T23:59:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '205.1'},
#  {'time': '2023-10-29T23:59:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '206.7'},
#  {'time': '2023-10-29T23:59:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '201.5'},
#  {'time': '2023-10-29T23:59:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '203.7'},
#  {'time': '2023-10-29T23:59:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '201.5'},
#  {'time': '2023-10-29T23:59:49+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:49+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:49+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:49+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '200.1'},
#  {'time': '2023-10-29T23:59:48+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:48+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:48+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:48+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '199'},
#  {'time': '2023-10-29T23:59:47+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:47+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:47+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:47+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '200.6'},
#  {'time': '2023-10-29T23:59:46+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:46+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:59:46+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:46+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '202.6'},
#  {'time': '2023-10-29T23:59:45+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:45+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:45+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:45+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '202'},
#  {'time': '2023-10-29T23:59:44+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:44+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:44+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:44+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '199.3'},
#  {'time': '2023-10-29T23:59:43+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:43+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:43+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:43+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '197.9'},
#  {'time': '2023-10-29T23:59:42+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:42+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:42+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:42+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '196.6'},
#  {'time': '2023-10-29T23:59:41+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:41+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:41+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:41+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '199.4'},
#  {'time': '2023-10-29T23:59:40+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:40+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:40+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:40+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '201.4'},
#  {'time': '2023-10-29T23:59:39+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:39+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:39+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:39+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '191'},
#  {'time': '2023-10-29T23:59:38+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:38+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:38+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:38+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '177.6'},
#  {'time': '2023-10-29T23:59:37+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:37+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:37+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:37+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '163'},
#  {'time': '2023-10-29T23:59:36+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:36+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:36+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:36+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '141.7'},
#  {'time': '2023-10-29T23:59:35+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:35+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:35+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:35+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '91.1'},
#  {'time': '2023-10-29T23:59:34+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:34+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:34+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:34+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '88'},
#  {'time': '2023-10-29T23:59:33+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:33+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:59:33+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:33+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '60.1'},
#  {'time': '2023-10-29T23:59:32+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:32+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:32+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099552'},
#  {'time': '2023-10-29T23:59:32+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '56.8'},
#  {'time': '2023-10-29T23:59:31+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:31+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099552'},
#  {'time': '2023-10-29T23:59:31+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:31+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '54.4'},
#  {'time': '2023-10-29T23:59:30+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:30+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099552'},
#  {'time': '2023-10-29T23:59:30+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:30+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '56.1'},
#  {'time': '2023-10-29T23:59:29+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:29+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:29+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099552'},
#  {'time': '2023-10-29T23:59:29+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '78.6'},
#  {'time': '2023-10-29T23:59:28+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:28+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09955'},
#  {'time': '2023-10-29T23:59:28+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:28+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '85.9'},
#  {'time': '2023-10-29T23:59:27+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:27+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099552'},
#  {'time': '2023-10-29T23:59:27+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:27+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '96.8'},
#  {'time': '2023-10-29T23:59:26+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:26+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:26+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09955'},
#  {'time': '2023-10-29T23:59:26+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '113.5'},
#  {'time': '2023-10-29T23:59:25+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:25+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09955'},
#  {'time': '2023-10-29T23:59:25+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:25+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '118.2'},
#  {'time': '2023-10-29T23:59:24+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:24+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09955'},
#  {'time': '2023-10-29T23:59:24+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:24+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '122.8'},
#  {'time': '2023-10-29T23:59:23+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:23+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:23+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09955'},
#  {'time': '2023-10-29T23:59:23+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '132.1'},
#  {'time': '2023-10-29T23:59:22+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:22+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09955'},
#  {'time': '2023-10-29T23:59:22+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:22+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '140.8'},
#  {'time': '2023-10-29T23:59:21+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:21+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099548'},
#  {'time': '2023-10-29T23:59:21+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:21+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '152.6'},
#  {'time': '2023-10-29T23:59:20+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:20+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:20+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099546'},
#  {'time': '2023-10-29T23:59:20+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '157.1'},
#  {'time': '2023-10-29T23:59:19+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:19+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099546'},
#  {'time': '2023-10-29T23:59:19+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:19+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '158.5'},
#  {'time': '2023-10-29T23:59:18+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:18+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099546'},
#  {'time': '2023-10-29T23:59:18+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:18+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '171.4'},
#  {'time': '2023-10-29T23:59:17+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:17+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:17+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099545'},
#  {'time': '2023-10-29T23:59:17+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '178.7'},
#  {'time': '2023-10-29T23:59:16+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:16+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099545'},
#  {'time': '2023-10-29T23:59:16+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:16+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '184.6'},
#  {'time': '2023-10-29T23:59:15+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:15+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099543'},
#  {'time': '2023-10-29T23:59:15+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:15+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '182.9'},
#  {'time': '2023-10-29T23:59:14+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:14+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:14+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099543'},
#  {'time': '2023-10-29T23:59:14+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '186.9'},
#  {'time': '2023-10-29T23:59:13+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:13+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099543'},
#  {'time': '2023-10-29T23:59:13+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:13+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '183.5'},
#  {'time': '2023-10-29T23:59:12+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320873'},
#  {'time': '2023-10-29T23:59:12+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09954'},
#  {'time': '2023-10-29T23:59:12+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:12+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '183.8'},
#  {'time': '2023-10-29T23:59:11+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:11+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:11+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09954'},
#  {'time': '2023-10-29T23:59:11+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '185.8'},
#  {'time': '2023-10-29T23:59:10+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:10+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099539'},
#  {'time': '2023-10-29T23:59:10+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:10+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '185.1'},
#  {'time': '2023-10-29T23:59:09+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:09+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099539'},
#  {'time': '2023-10-29T23:59:09+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:09+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '179.5'},
#  {'time': '2023-10-29T23:59:08+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:08+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:08+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099539'},
#  {'time': '2023-10-29T23:59:08+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '175.3'},
#  {'time': '2023-10-29T23:59:07+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:07+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099537'},
#  {'time': '2023-10-29T23:59:07+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:07+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '169'},
#  {'time': '2023-10-29T23:59:06+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:06+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099535'},
#  {'time': '2023-10-29T23:59:06+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:06+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '171.1'},
#  {'time': '2023-10-29T23:59:05+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:05+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:05+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099533'},
#  {'time': '2023-10-29T23:59:05+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '169.2'},
#  {'time': '2023-10-29T23:59:04+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:04+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099531'},
#  {'time': '2023-10-29T23:59:04+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:04+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '164.4'},
#  {'time': '2023-10-29T23:59:03+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:03+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09953'},
#  {'time': '2023-10-29T23:59:03+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:03+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '163.1'},
#  {'time': '2023-10-29T23:59:02+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:02+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:02+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09953'},
#  {'time': '2023-10-29T23:59:02+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '160.2'},
#  {'time': '2023-10-29T23:59:01+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:01+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099527'},
#  {'time': '2023-10-29T23:59:01+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:01+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '162.1'},
#  {'time': '2023-10-29T23:59:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:59:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099525'},
#  {'time': '2023-10-29T23:59:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:59:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '161.2'},
#  {'time': '2023-10-29T23:58:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099524'},
#  {'time': '2023-10-29T23:58:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '159.5'},
#  {'time': '2023-10-29T23:58:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099524'},
#  {'time': '2023-10-29T23:58:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '157.2'},
#  {'time': '2023-10-29T23:58:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099522'},
#  {'time': '2023-10-29T23:58:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '157'},
#  {'time': '2023-10-29T23:58:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099522'},
#  {'time': '2023-10-29T23:58:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '159'},
#  {'time': '2023-10-29T23:58:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09952'},
#  {'time': '2023-10-29T23:58:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '160.5'},
#  {'time': '2023-10-29T23:58:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09952'},
#  {'time': '2023-10-29T23:58:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '159.1'},
#  {'time': '2023-10-29T23:58:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.09952'},
#  {'time': '2023-10-29T23:58:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '164.5'},
#  {'time': '2023-10-29T23:58:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099518'},
#  {'time': '2023-10-29T23:58:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '164.9'},
#  {'time': '2023-10-29T23:58:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099518'},
#  {'time': '2023-10-29T23:58:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '164.3'},
#  {'time': '2023-10-29T23:58:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '164.1'},
#  {'time': '2023-10-29T23:58:49+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:49+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:49+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:49+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '163.4'},
#  {'time': '2023-10-29T23:58:48+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:48+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:48+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:48+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '162.9'},
#  {'time': '2023-10-29T23:58:47+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:47+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:47+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:47+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '162'},
#  {'time': '2023-10-29T23:58:46+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:46+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:46+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:46+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '166.2'},
#  {'time': '2023-10-29T23:58:45+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:45+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:45+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:45+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '166.3'},
#  {'time': '2023-10-29T23:58:44+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:44+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:44+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:44+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '166.6'},
#  {'time': '2023-10-29T23:58:43+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:43+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:43+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:43+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '170.9'},
#  {'time': '2023-10-29T23:58:42+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:42+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099516'},
#  {'time': '2023-10-29T23:58:42+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:42+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '171.9'},
#  {'time': '2023-10-29T23:58:41+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:41+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:41+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099518'},
#  {'time': '2023-10-29T23:58:41+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '170.3'},
#  {'time': '2023-10-29T23:58:40+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:40+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099518'},
#  {'time': '2023-10-29T23:58:40+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:40+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '173.6'},
#  {'time': '2023-10-29T23:58:39+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:39+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099522'},
#  {'time': '2023-10-29T23:58:39+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:39+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '172.9'},
#  {'time': '2023-10-29T23:58:38+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:58:38+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:38+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099524'},
#  {'time': '2023-10-29T23:58:38+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '178.4'},
#  {'time': '2023-10-29T23:58:37+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320877'},
#  {'time': '2023-10-29T23:58:37+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099525'},
# ...
#  {'time': '2023-10-29T23:56:17+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:56:17+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:16+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32088'},
#  {'time': '2023-10-29T23:56:16+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:56:16+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:16+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '228.5'},
#  {'time': '2023-10-29T23:56:15+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32088'},
#  {'time': '2023-10-29T23:56:15+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:56:15+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:15+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '232.2'},
#  {'time': '2023-10-29T23:56:14+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '246.1'},
#  {'time': '2023-10-29T23:56:14+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32088'},
#  {'time': '2023-10-29T23:56:14+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:56:14+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:13+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32088'},
#  {'time': '2023-10-29T23:56:13+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:56:13+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:13+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '252.9'},
#  {'time': '2023-10-29T23:56:12+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32088'},
#  {'time': '2023-10-29T23:56:12+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:56:12+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:12+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '258.1'},
#  {'time': '2023-10-29T23:56:11+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '271.8'},
#  {'time': '2023-10-29T23:56:11+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32088'},
#  {'time': '2023-10-29T23:56:11+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:56:11+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:10+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32088'},
#  {'time': '2023-10-29T23:56:10+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099558'},
#  {'time': '2023-10-29T23:56:10+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:10+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '276.4'},
#  {'time': '2023-10-29T23:56:09+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32088'},
#  {'time': '2023-10-29T23:56:09+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:56:09+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:09+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '289.8'},
#  {'time': '2023-10-29T23:56:08+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '285.8'},
#  {'time': '2023-10-29T23:56:08+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320885'},
#  {'time': '2023-10-29T23:56:08+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:56:08+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:07+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320885'},
#  {'time': '2023-10-29T23:56:07+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099556'},
#  {'time': '2023-10-29T23:56:07+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:07+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '276.1'},
#  {'time': '2023-10-29T23:56:06+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320885'},
#  {'time': '2023-10-29T23:56:06+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:56:06+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:06+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '269'},
#  {'time': '2023-10-29T23:56:05+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '252.1'},
#  {'time': '2023-10-29T23:56:05+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320885'},
#  {'time': '2023-10-29T23:56:05+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:56:05+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:04+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320885'},
#  {'time': '2023-10-29T23:56:04+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:56:04+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:04+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '238.4'},
#  {'time': '2023-10-29T23:56:03+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320885'},
#  {'time': '2023-10-29T23:56:03+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:56:03+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:03+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '241.9'},
#  {'time': '2023-10-29T23:56:02+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '226.4'},
#  {'time': '2023-10-29T23:56:02+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320885'},
#  {'time': '2023-10-29T23:56:02+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:56:02+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:01+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320885'},
#  {'time': '2023-10-29T23:56:01+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:56:01+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:01+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '229.1'},
#  {'time': '2023-10-29T23:56:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:56:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:56:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:56:00+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '254.9'},
#  {'time': '2023-10-29T23:55:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '260.1'},
#  {'time': '2023-10-29T23:55:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:59+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:58+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '259.6'},
#  {'time': '2023-10-29T23:55:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:57+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '261.8'},
#  {'time': '2023-10-29T23:55:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '264.3'},
#  {'time': '2023-10-29T23:55:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:56+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:55+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '269.4'},
#  {'time': '2023-10-29T23:55:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:54+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '274.8'},
#  {'time': '2023-10-29T23:55:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '264.2'},
#  {'time': '2023-10-29T23:55:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:53+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:52+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '266.5'},
#  {'time': '2023-10-29T23:55:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.32089'},
#  {'time': '2023-10-29T23:55:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099552'},
#  {'time': '2023-10-29T23:55:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'},
#  {'time': '2023-10-29T23:55:51+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '266.7'},
#  {'time': '2023-10-29T23:55:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'value': '260.9'},
#  {'time': '2023-10-29T23:55:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'value': '59.320892'},
#  {'time': '2023-10-29T23:55:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'value': '18.099554'},
#  {'time': '2023-10-29T23:55:50+00:00',
#   'vessel_id': 'mmsi_265585310',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'value': '0'}]

# %%
datavessel_data = fetch_vessel_data("imo_7943354","2024-11-11T00:00:00","2024-11-13T00:00:00", time_bucket="5 minutes")

# %%
datavessel_data
# Out:
# [{'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 7.772294142},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 242.51033333333334},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 63.86285264},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 20.739114796666666},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 7.376884941666667},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 238.29633333333334},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 63.86284823},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 20.739114603333334},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 7.595264062666667},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 267.75966666666665},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 63.86284987},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 20.73912944},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 7.565116285},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 270.60133333333334},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 63.86284767666667},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 20.739132226666666},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 7.355333344333333},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 286.7626666666667},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 63.86285334},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 20.73912984},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 7.677471076333333},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 294.54133333333334},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 63.8628506},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 20.739125706666666},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 7.369516466333334},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 263.25933333333336},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 63.86286351333333},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 20.739116593333332},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 7.758086437666667},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 270.867},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 63.86287052},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 20.739123966666668},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 7.416906990333334},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 291.5473333333333},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 63.86287048333333},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 20.73913082},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 7.711517908},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 255.67},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 63.862863966666666},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 20.73913050333333},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 7.394162043},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 271.656},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 63.86286337},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 20.739120596666666},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 7.752718762},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 240.682},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 63.86286247333334},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 20.739119673333335},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T00:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T00:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 7.407201843},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 265.918},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 63.86285204666667},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 20.739124643333334},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 7.756682797},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 251.82666666666665},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 63.86284462},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 20.739124043333334},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 7.368389531666667},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 246.944},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 63.862848783333334},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 20.739125626666667},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 7.676520543333333},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 288.846},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 63.862848836666664},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 20.73912095},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 7.364806984333334},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 279.0783333333333},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 63.862851113333335},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 20.7391274},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:20:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:22:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 7.6958378},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 290.0756666666667},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 63.86284981666667},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 20.739122446666666},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:25:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:27:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 0.84},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 7.4014386126666665},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 290.2583333333333},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 63.86285676333333},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 20.739131356666668},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:30:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:32:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 7.676528873333333},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 292.28833333333336},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 63.862856953333335},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 20.739131723333333},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:37:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 7.391205161333334},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 275.281},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 63.862851},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 20.739136646666665},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 7.672049945666667},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 286.763},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 63.86285446},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 20.739122326666667},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 7.416835952333333},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 280.2323333333333},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 63.86285242},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 20.7391139},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 7.729278764666667},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 279.9236666666667},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 63.862850613333336},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 20.739112203333335},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T01:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T01:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 7.445706775333333},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 278.88866666666667},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 63.86285446666667},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 20.739119676666668},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T02:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T02:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T02:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T02:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T02:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T02:07:29.5+00:00',
#   'avg_value': 7.702996710333333},
#  {'bucket': '2024-11-11T02:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T02:07:29.5+00:00',
#   'avg_value': 0.0},
# ...
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T07:37:29.5+00:00',
#   'avg_value': 20.86520772},
#  {'bucket': '2024-11-11T07:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T07:37:29.5+00:00',
#   'avg_value': 5.689333333333333},
#  {'bucket': '2024-11-11T07:35:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T07:37:29.5+00:00',
#   'avg_value': 13.191427755333333},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 0.6},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 27.909890283333333},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 1027.5200008},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 220.22766666666666},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 63.80577196},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 20.869014486666668},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 2.209000009},
#  {'bucket': '2024-11-11T07:40:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T07:42:29.5+00:00',
#   'avg_value': 9.92065579},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 0.24},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 23.636875976666666},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 1004.2166676666667},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 185.08166666666668},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 63.80512008},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 20.868159006666666},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:45:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T07:47:29.5+00:00',
#   'avg_value': 8.514086794},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 0.84},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 28.640960406666668},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 1010.1600002},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 243.98466666666667},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 63.80511698666667},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 20.868146863333333},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 0.14733333366666668},
#  {'bucket': '2024-11-11T07:50:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T07:52:29.5+00:00',
#   'avg_value': 8.462392922333333},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 44.873120793333335},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 1000.4000012},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 233.011},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 63.809000733333335},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 20.86719183},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 7.276333410333334},
#  {'bucket': '2024-11-11T07:55:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T07:57:29.5+00:00',
#   'avg_value': 8.487292765333333},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 42.11351663333333},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 996.380009},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 318.06766666666664},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 63.818174076666665},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 20.85227044},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 8.59299987},
#  {'bucket': '2024-11-11T08:00:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T08:02:29.5+00:00',
#   'avg_value': 8.577935694666667},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 0.84},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 42.07484050666667},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 996.6000056},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 319.6023333333333},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 63.82717295333333},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 20.834391043333333},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 8.60799977},
#  {'bucket': '2024-11-11T08:05:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T08:07:29.5+00:00',
#   'avg_value': 8.421626421},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 42.00287914333333},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 994.2333375333334},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 318.76866666666666},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 63.83601719666667},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 20.817068053333333},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 8.423000143333333},
#  {'bucket': '2024-11-11T08:10:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T08:12:29.5+00:00',
#   'avg_value': 8.420186666},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'boiler_fuelcons_lph_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'electricalbus_shorepower_kw_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'engineaux_power_kw_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 0.0},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_fuelcons_lph_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 42.15754427},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'enginemain_speed_rpm_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 993.0533359333333},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_cog_deg_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 319.1326666666667},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_latitude_deg_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 63.84484439333333},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_longitude_deg_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 20.79950811},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'positioningsystem_sog_kn_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 8.50899991},
#  {'bucket': '2024-11-11T08:15:00+00:00',
#   'vessel_id': 'imo_7943354',
#   'parameter_id': 'shaftgenerator_power_kw_1',
#   'avg_time': '2024-11-11T08:17:29.5+00:00',
#   'avg_value': 9.876955572333333},
#  ...]
